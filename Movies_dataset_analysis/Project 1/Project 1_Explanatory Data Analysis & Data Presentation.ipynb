# %% [markdown]
# # Python Data Science with Pandas: Master 12 Advanced Projects
# ## Project 1: Explanatory Data Analysis and Data Presentation (Movies Dataset)

# %% [markdown]
# ### Import data:
#
# __Some additional information on Features/Columns__:
#
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
# Load modules and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import the movies dataset
movies = pd.read_csv("movies_complete.csv")
movies
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %% [markdown]
# ### Inspect data

# %%
# Get information on the number of data columns and entries, number of non-null entries for each column and the data type of each column
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
# Descriptive statistics
movies.describe()
# Out:
#                   id  budget_musd  revenue_musd    vote_count  vote_average  \
# count   44691.000000  8854.000000   7385.000000  44691.000000  42077.000000
# mean   107186.242845    21.669886     68.968649    111.653778      6.003341
# std    111806.362236    34.359837    146.608966    495.322313      1.281060
# min         2.000000     0.000001      0.000001      0.000000      0.000000
# 25%     26033.500000     2.000000      2.405420      3.000000      5.300000
# 50%     59110.000000     8.200000     16.872671     10.000000      6.100000
# 75%    154251.000000    25.000000     67.642693     35.000000      6.800000
# max    469172.000000   380.000000   2787.965087  14075.000000     10.000000
#
#          popularity       runtime     cast_size     crew_size
# count  44691.000000  43179.000000  44691.000000  44691.000000
# mean       2.957460     97.566850     12.479090     10.313643
# std        6.040008     34.653409     12.124663     15.892154
# ...

# %%
# Get the number of null entries per column
movies.isnull().sum()
# Out:
# id                           0
# title                        0
# tagline                  24407
# release_date                34
# genres                    2105
# belongs_to_collection    40228
# original_language           10
# budget_musd              35837
# revenue_musd             37306
# production_companies     11335
# production_countries      5856
# vote_count                   0
# vote_average              2614
# popularity                   0
# runtime                   1512
# overview                   951
# spoken_languages          3597
# poster_path                224
# cast                      2189
# cast_size                    0
# crew_size                    0
# director                   731
# dtype: int64

# %% [markdown]
# ### Sort and filter data to find the best and worst movies with the:
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %%
# Sort by highest revenue
movies.sort_values(by=["revenue_musd"], ascending=False)[["title","revenue_musd"]].head(5)
# Out:
#                               title  revenue_musd
# 14448                        Avatar   2787.965087
# 26265  Star Wars: The Force Awakens   2068.223624
# 1620                        Titanic   1845.034188
# 17669                  The Avengers   1519.557910
# 24812                Jurassic World   1513.528810

# %%
# Sort by highest budget
movies.sort_values(by=["budget_musd"], ascending=False)[["title","budget_musd"]].head(5)
# Out:
#                                              title  budget_musd
# 16986  Pirates of the Caribbean: On Stranger Tides        380.0
# 11743     Pirates of the Caribbean: At World's End        300.0
# 26268                      Avengers: Age of Ultron        280.0
# 10985                             Superman Returns        270.0
# 18517                                  John Carter        260.0

# %%
# Sort by highest profit (revenue - budget)
movies = movies.replace({"revenue_musd":{np.NaN,0}, "budget_musd":{np.NaN,0}})
movies_profit = movies.loc[:,["title", "revenue_musd", "budget_musd"]]
movies_profit.loc[:,["profit_musd"]] = movies_profit.revenue_musd - movies_profit.budget_musd
movies_profit.sort_values(by=["profit_musd"], ascending=False).head(5)
# Out:
#                               title  revenue_musd  budget_musd  profit_musd
# 14448                        Avatar   2787.965087        237.0  2550.965087
# 26265  Star Wars: The Force Awakens   2068.223624        245.0  1823.223624
# 1620                        Titanic   1845.034188        200.0  1645.034188
# 24812                Jurassic World   1513.528810        150.0  1363.528810
# 28501                     Furious 7   1506.249360        190.0  1316.249360

# %%
# Sort by lowest profit (revenue - budget)
movies_profit.sort_values(by=["profit_musd"], ascending=True).head(5)
# Out:
#                                              title  revenue_musd  budget_musd  \
# 20959                              The Lone Ranger     89.289910   255.000000
# 7164                                     The Alamo     25.819961   145.000000
# 16659                              Mars Needs Moms     38.992758   150.000000
# 43611  Valerian and the City of a Thousand Planets     90.024292   197.471676
# 2684                              The 13th Warrior     61.698899   160.000000
#
#        profit_musd
# 20959  -165.710090
# 7164   -119.180039
# 16659  -111.007242
# 43611  -107.447384
# 2684    -98.301101

# %%
# Sort by highest return on investment
movies_roi = movies.loc[:,["title", "revenue_musd", "budget_musd"]]
movies_roi.loc[:,"return_on_investment_musd"] = movies_roi["revenue_musd"] / movies_roi["budget_musd"]
movies_roi.sort_values(by=["return_on_investment_musd"], ascending=False).head(5)
# Out:
#                          title  revenue_musd  budget_musd  \
# 3965            Less Than Zero     12.396383     0.000001
# 3312              Modern Times      8.500000     0.000001
# 14270    Welcome to Dongmakgol     33.579813     0.000008
# 22041           Aquí Entre Nos      2.755584     0.000001
# 2284   The Karate Kid, Part II    115.103979     0.000113
#
#        return_on_investment_musd
# 3965                1.239638e+07
# 3312                8.500000e+06
# 14270               4.197477e+06
# 22041               2.755584e+06
# 2284                1.018619e+06

# %%
# Sort by lowest return on investment
movies_roi.sort_values(by=["return_on_investment_musd"], ascending=True).head(5)
# Out:
#                          title  revenue_musd  budget_musd  \
# 6955           Chasing Liberty      0.000012    23.000000
# 8041               The Cookout      0.000012    16.000000
# 2636   Never Talk to Strangers      0.000006     6.400000
# 12859           To Rob a Thief      0.000006     4.002313
# 17381                 Deadfall      0.000018    10.000000
#
#        return_on_investment_musd
# 6955                5.217391e-07
# 8041                7.500000e-07
# 2636                9.375000e-07
# 12859               1.499133e-06
# 17381               1.800000e-06

# %%
# Sort by highest number of votes
movies.sort_values(by=["vote_count"], ascending=False)[["title", "vote_count"]].head(5)
# Out:
#                  title  vote_count
# 15368        Inception     14075.0
# 12396  The Dark Knight     12269.0
# 14448           Avatar     12114.0
# 17669     The Avengers     12000.0
# 26272         Deadpool     11444.0

# %%
# Sort by highest rating in movies with 10 or more ratings
movies[movies.vote_count>10].sort_values(by=["vote_average"], ascending=False)[["title","vote_count","vote_average"]].head()
# Out:
#                              title  vote_count  vote_average
# 42626              Planet Earth II        50.0           9.5
# 18462                The Civil War        15.0           9.2
# 10233  Dilwale Dulhania Le Jayenge       661.0           9.1
# 42822                       Cosmos        41.0           9.1
# 38323        Bruce Lee: The Legend        19.0           8.9

# %%
# Sort by lowest rating in movies with 10 or more ratings
movies[movies.vote_count>10].sort_values(by=["vote_average"], ascending=True)[["title","vote_count","vote_average"]].head(5)
# Out:
#                             title  vote_count  vote_average
# 41602        Call Me by Your Name        18.0           0.0
# 25418                 Santa Claus        12.0           1.6
# 7030     The Beast of Yucca Flats        18.0           1.6
# 32437            Saving Christmas        25.0           1.7
# 43502  The Wild World of Batwoman        12.0           1.8

# %%
# Highest popularity
movies.sort_values(by=["popularity"], ascending=False)[["title","popularity"]].head(5)
# Out:
#                       title  popularity
# 30330               Minions  547.488298
# 32927          Wonder Woman  294.337037
# 41556  Beauty and the Beast  287.253654
# 42940           Baby Driver  228.032744
# 24187            Big Hero 6  213.849907

# %%
# Create a user defined function to find the n best or worst movies based on a minimum user vote and revenue, sort by a user defined column
def movie_filter(dataset, n, sort_by, ascending, min_vote_average, min_revenue):
    dataset = pd.DataFrame(dataset)
    filters = (dataset.vote_average > min_vote_average) & (dataset.revenue_musd > min_revenue)
    filtered_dataset = dataset[filters].sort_values(by=[sort_by], ascending=ascending).head(n)
    return filtered_dataset[["title", sort_by, "vote_average", "revenue_musd"]]

movie_filter(movies, 5, "popularity", False, 5, 2)
# Out:
#                       title  popularity  vote_average  revenue_musd
# 30330               Minions  547.488298           6.4   1156.730962
# 32927          Wonder Woman  294.337037           7.2    820.580447
# 41556  Beauty and the Beast  287.253654           6.8   1262.886337
# 42940           Baby Driver  228.032744           7.2    224.511319
# 24187            Big Hero 6  213.849907           7.8    652.105443

# %% [markdown]
# ## Find your next Movie
# 3. __Filter__ the Dataset for movies that meet the following conditions:
#
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__
#
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__
#
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__
#
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
# Filter dataset for science fiction, action movies with Bruce Willis (sorted from high to low rating)
genre_filter = movies.genres.str.contains("science fiction", False) & movies.genres.str.contains("action", False)
cast_filter = movies.cast.str.contains("Bruce Willis", False)

movies[genre_filter & cast_filter][["title", "genres", "cast", "vote_average"]].sort_values(by=["vote_average"], ascending=False).head(5)
# Out:
#                        title  \
# 1448       The Fifth Element
# 19218                 Looper
# 1786              Armageddon
# 14135             Surrogates
# 20333  G.I. Joe: Retaliation
#
#                                                   genres  \
# 1448   Adventure|Fantasy|Action|Thriller|Science Fiction
# 19218                    Action|Thriller|Science Fiction
# 1786           Action|Thriller|Science Fiction|Adventure
# 14135                    Action|Science Fiction|Thriller
# 20333          Adventure|Action|Science Fiction|Thriller
#
#                                                     cast  vote_average
# 1448   Bruce Willis|Gary Oldman|Ian Holm|Milla Jovovi...           7.3
# 19218  Joseph Gordon-Levitt|Bruce Willis|Emily Blunt|...           6.6
# 1786   Bruce Willis|Billy Bob Thornton|Ben Affleck|Li...           6.5
# 14135  Bruce Willis|Radha Mitchell|Rosamund Pike|Jame...           5.9
# 20333  Dwayne Johnson|D.J. Cotrona|Adrianne Palicki|B...           5.4

# %%
# Filter for movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)
cast_filter = movies.cast.str.contains("Uma Thurman", False)
director_filter = movies.director == ("Quentin Tarantino")

movies[cast_filter & director_filter][["title","cast","director","runtime"]].sort_values(by=["runtime"], ascending=True)
# Out:
#                   title                                               cast  \
# 6667  Kill Bill: Vol. 1  Uma Thurman|Lucy Liu|Vivica A. Fox|Daryl Hanna...
# 7208  Kill Bill: Vol. 2  Uma Thurman|David Carradine|Daryl Hannah|Micha...
# 291        Pulp Fiction  John Travolta|Samuel L. Jackson|Uma Thurman|Br...
#
#                director  runtime
# 6667  Quentin Tarantino    111.0
# 7208  Quentin Tarantino    136.0
# 291   Quentin Tarantino    154.0

# %%
# Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)
production_com_filter = movies.production_companies.str.contains("Pixar", False)
date_filter=movies.release_date.between("2010-01-01", "2015-12-31")
movies[production_com_filter & date_filter][["title","production_companies","release_date","revenue_musd"]].sort_values(by=["revenue_musd"], ascending=False).head(5)
# Out:
#                      title                          production_companies  \
# 15236          Toy Story 3  Walt Disney Pictures|Pixar Animation Studios
# 29957           Inside Out  Walt Disney Pictures|Pixar Animation Studios
# 20888  Monsters University  Walt Disney Pictures|Pixar Animation Studios
# 17220               Cars 2  Walt Disney Pictures|Pixar Animation Studios
# 18900                Brave  Walt Disney Pictures|Pixar Animation Studios
#
#       release_date  revenue_musd
# 15236   2010-06-16   1066.969703
# 29957   2015-06-09    857.611174
# 20888   2013-06-20    743.559607
# 17220   2011-06-11    559.852396
# 18900   2012-06-21    538.983207

# %%
# Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)
genre_filter = movies.genres.str.contains("thriller", False) | movies.genres.str.contains("thriller", False)
language_filter = movies.original_language == ("en")
rating_filter = movies.vote_average >= 7.5

movies[genre_filter & language_filter & rating_filter][["title","genres","original_language","vote_average","release_date"]].sort_values(by=["release_date"],ascending=False).head(5)
# Out:
#                    title                             genres original_language  \
# 43941            Dunkirk  Action|Drama|History|Thriller|War                en
# 42624  The Book of Henry               Thriller|Drama|Crime                en
# 42877         Tomato Red                     Drama|Thriller                en
# 44447             Zero 3                           Thriller                en
# 40525       The Thinning                           Thriller                en
#
#        vote_average release_date
# 43941           7.5   2017-07-19
# 42624           7.6   2017-06-16
# 42877           8.0   2017-02-24
# 44447           8.7   2017-01-27
# 40525           7.6   2016-10-12

# %% [markdown]
# ## Are Franchises more successful?
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:
#
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %%
# Create a subset with all data columns of interest and calculate ROI
movies["ROI"] = movies.revenue_musd / movies.budget_musd
movies_subset = movies[["title","belongs_to_collection","revenue_musd","budget_musd","popularity","vote_average", "ROI"]]
movies_subset.head(5)
# Out:
#                          title           belongs_to_collection  revenue_musd  \
# 0                    Toy Story            Toy Story Collection    373.554033
# 1                      Jumanji                             NaN    262.797249
# 2             Grumpier Old Men       Grumpy Old Men Collection           NaN
# 3            Waiting to Exhale                             NaN     81.452156
# 4  Father of the Bride Part II  Father of the Bride Collection     76.578911
#
#    budget_musd  popularity  vote_average        ROI
# 0         30.0   21.946943           7.7  12.451801
# 1         65.0   17.015539           6.9   4.043035
# 2          NaN   11.712900           6.5        NaN
# 3         16.0    3.859495           6.1   5.090760
# 4          NaN    8.387519           5.7        NaN

# %%
# Create filters to select franchises or stand-alone movies
franchises = movies.belongs_to_collection.notna()
stand_alones = movies.belongs_to_collection.isna()

# %%
# Compare franchise or stand-alone movie statistics
franchise_revenue = movies_subset.groupby(franchises).revenue_musd.mean()[1]
stand_alone_revenue = movies_subset.groupby(stand_alones).revenue_musd.mean()[1]
franchise_ROI = movies_subset.groupby(franchises).ROI.mean()[1]
stand_alone_ROI = movies_subset.groupby(stand_alones).ROI.mean()[1]
franchise_budget = movies_subset.groupby(franchises).budget_musd.mean()[1]
stand_alone_budget = movies_subset.groupby(stand_alones).budget_musd.mean()[1]
franchise_pop = movies_subset.groupby(franchises).popularity.mean()[1]
stand_alone_pop = movies_subset.groupby(stand_alones).popularity.mean()[1]
franchise_ratings = movies_subset.groupby(franchises).vote_average.mean()[1]
stand_alone_ratings = movies_subset.groupby(stand_alones).vote_average.mean()[1]

# %%
franchise_revenue
# Out:
# 165.70819260175796

# %%
stand_alone_revenue
# Out:
# 44.7428140060955

# %%
franchise_ROI
# Out:
# 856.4046224739209

# %%
stand_alone_ROI
# Out:
# 6966.3906502038735

# %%
franchise_budget
# Out:
# 38.31984712958281

# %%
stand_alone_budget
# Out:
# 18.047741174779976

# %%
franchise_pop
# Out:
# 6.245051188662335

# %%
stand_alone_pop
# Out:
# 2.592726062543502

# %%
franchise_ratings
# Out:
# 5.956805807622504

# %%
stand_alone_ratings
# Out:
# 6.008787066287929

# %% [markdown]
# ## Most Successful Franchises
# 5. __Find__ the __most successful Franchises__ in terms of
#
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
# Find the most successful franchise in terms of total number of movies
movies[franchises][["title","belongs_to_collection"]].groupby("belongs_to_collection").count().sort_values(by=["title"], ascending = False).head(5)
# Out:
#                                title
# belongs_to_collection
# The Bowery Boys                   29
# Totò Collection                   27
# James Bond Collection             26
# Zatôichi: The Blind Swordsman     26
# The Carry On Collection           25

# %%
# Create a table with all the required properties for comparison
succ_franchise = movies.groupby("belongs_to_collection").agg({"title":"count","budget_musd":["sum","mean"],"revenue_musd":["sum","mean"],"vote_average":"mean"})
succ_franchise
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2       130.0  65.0   366.780087
# 00 Schneider Filmreihe                   1         0.0   NaN     0.000000
# 08/15 Collection                         1         0.0   NaN     0.000000
# 100 Girls Collection                     2         0.0   NaN     0.000000
# 101 Dalmatians (Animated) Collection     2         4.0   4.0   215.880014
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1         0.0   NaN     0.000000
# Чебурашка и крокодил Гена                1         0.0   NaN     0.000000
# Что Творят мужчины! (Коллекция)          2         2.0   2.0     0.000000
# 男はつらいよ シリーズ                              3         0.0   NaN     0.000000
# ...

# %%
# Find the most successful franchise in terms of the total number of movies
succ_franchise.sort_values(by=("title","count"), ascending=False).head(5)
# Out:
#                               title budget_musd            revenue_musd  \
#                               count         sum       mean          sum
# belongs_to_collection
# The Bowery Boys                  29        0.00        NaN     0.000000
# Totò Collection                  27        0.00        NaN     0.000000
# James Bond Collection            26     1539.65  59.217308  7106.970239
# Zatôichi: The Blind Swordsman    26        0.00        NaN     0.000000
# The Carry On Collection          25        0.00        NaN     0.000000
#
#                                           vote_average
#                                      mean         mean
# belongs_to_collection
# The Bowery Boys                       NaN     6.675000
# Totò Collection                       NaN     6.837037
# James Bond Collection          273.345009     6.338462
# Zatôichi: The Blind Swordsman         NaN     6.403846
# The Carry On Collection               NaN     6.168000

# %%
# Find the most successful franchise in terms of the total and mean budget
succ_franchise.sort_values(by=[("budget_musd","sum"),("budget_musd","mean")], ascending=[False,False]).head(5)
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# James Bond Collection                  26     1539.65   59.217308
# Harry Potter Collection                 8     1280.00  160.000000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
# The Fast and the Furious Collection     8     1009.00  126.125000
# X-Men Collection                        6      983.00  163.833333
#
#                                     revenue_musd             vote_average
#                                              sum        mean         mean
# belongs_to_collection
# James Bond Collection                7106.970239  273.345009     6.338462
# Harry Potter Collection              7707.367425  963.420928     7.537500
# Pirates of the Caribbean Collection  4521.576826  904.315365     6.880000
# The Fast and the Furious Collection  5125.098793  640.637349     6.662500
# ...

# %%
# Find the most successful franchise in terms of the total and mean revenue
succ_franchise.sort_values(by=[("revenue_musd","sum"),("revenue_musd","mean")], ascending=[False,False]).head(5)
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# Harry Potter Collection                 8     1280.00  160.000000
# Star Wars Collection                    8      854.35  106.793750
# James Bond Collection                  26     1539.65   59.217308
# The Fast and the Furious Collection     8     1009.00  126.125000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
#
#                                     revenue_musd             vote_average
#                                              sum        mean         mean
# belongs_to_collection
# Harry Potter Collection              7707.367425  963.420928     7.537500
# Star Wars Collection                 7434.494790  929.311849     7.375000
# James Bond Collection                7106.970239  273.345009     6.338462
# The Fast and the Furious Collection  5125.098793  640.637349     6.662500
# ...

# %%
# Find the most successful franchise in terms of the mean rating
succ_franchise.sort_values(by=[("vote_average","mean")], ascending=[False]).head(5)
# Out:
#                                     title budget_musd      revenue_musd       \
#                                     count         sum mean          sum mean
# belongs_to_collection
# Argo Collection                         1         0.0  NaN          0.0  NaN
# Bloodfight                              1         0.0  NaN          0.0  NaN
# Kenji Misumi's Trilogy of the Sword     1         0.0  NaN          0.0  NaN
# Dreileben                               1         0.0  NaN          0.0  NaN
# Алиса в стране чудес (Коллекция)        1         0.0  NaN          0.0  NaN
#
#                                     vote_average
#                                             mean
# belongs_to_collection
# Argo Collection                              9.3
# Bloodfight                                   9.0
# Kenji Misumi's Trilogy of the Sword          9.0
# Dreileben                                    9.0
# Алиса в стране чудес (Коллекция)             8.7

# %% [markdown]
# ## Most Successful Directors
#
# 6. __Find__ the __most successful Directors__ in terms of
#
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
# Create a dataframe with all our data of interest for downstream comparison
director_data = movies.groupby("director").agg({"title":"count","revenue_musd":"sum","vote_average":"mean"})
director_data
# Out:
#                      title  revenue_musd  vote_average
# director
#  Dale Trevillion\t       2      0.000000           4.0
#  Davide Manuli           1      0.000000           6.9
#  E.W. Swackhamer         1      0.000000           5.9
#  Vitaliy Vorobyov        1      0.000000           5.5
#  Yeon Sang-Ho            4      2.129768           6.6
# ...                    ...           ...           ...
# Ярополк Лапшин           1      0.000000          10.0
# پیمان معادی              1      0.000000           6.0
# 塩谷 直義                    1      0.000000           7.2
# 杰森·莫玛                    1      0.000000           5.8
# 진모영                      1      0.000000           6.0
#
# [17349 rows x 3 columns]

# %%
# Find the most successful directors in terms of total number of movies
succ_director_movies = director_data.sort_values(by=["title"],ascending=False).head(5)
succ_director_movies
# Out:
#                   title  revenue_musd  vote_average
# director
# John Ford            66     85.170757      6.381818
# Michael Curtiz       65     37.817500      5.998246
# Werner Herzog        54     24.572580      6.805556
# Alfred Hitchcock     53    250.107584      6.639623
# Woody Allen          49    993.970588      6.691837

# %%
# Graph the most successful directors in terms of total number of movies
succ_director_movies.plot(y="title",kind="bar",legend=False)
plt.xlabel("Director")
plt.ylabel("Title count")
plt.show()

# %%
# Find the most successful directors in terms of total revenue
succ_director_rev = director_data.sort_values(by=["revenue_musd"],ascending=False).head(5)
succ_director_rev
# Out:
#                   title  revenue_musd  vote_average
# director
# Steven Spielberg     33   9256.621422      6.893939
# Peter Jackson        13   6528.244659      7.138462
# Michael Bay          13   6437.466781      6.392308
# James Cameron        11   5900.610310      6.927273
# David Yates           9   5334.563196      6.700000

# %%
# Graph the most successful directors in terms of total revenue
succ_director_rev.plot(y="revenue_musd", kind="bar", legend=False)
plt.xlabel("Director")
plt.ylabel("Revenue MUSD")
plt.show()

# %%
# Find the most successful directors in terms of mean rating
succ_director_rating = director_data.sort_values(by=["vote_average"],ascending=False).head(5)
succ_director_rating
# Out:
#                       title  revenue_musd  vote_average
# director
# Antonis Sotiropoulos      1           0.0          10.0
# Brian Skeet               1           0.0          10.0
# Joel Heath                1           0.0          10.0
# Lukas Bossuyt             1           0.0          10.0
# Osman F. Seden            2           0.0          10.0

# %%
# Graph the most successful directors in terms of mean rating
succ_director_rating.plot(y="vote_average",kind="bar",legend=False)
plt.xlabel("Director")
plt.ylabel("Average rating")
plt.show()
