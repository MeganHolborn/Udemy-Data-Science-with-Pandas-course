# %% [markdown]
# # Project 2: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# ## Import modules and packages

# %%
import pandas as pd
import json
import requests
from functools import partial, reduce

# %% [markdown]
# ## Importing Data from JSON files

# %% [markdown]
# 1. __Import__ the json files __blockbusters.json__, __blockbusters2.json__, __blockbusters3.json__ and load the datasets into Pandas DataFrames.

# %%
# Transform data in json file into python object
# Blockbusters contains json in row format, while blockbusters2 contains json in columns format
with open("blockbusters.json") as f:
    blockbusters = json.load(f)
with open("blockbusters2.json") as f:
    blockbusters2 = json.load(f)

# %%
blockbusters
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 136},
#  {'title': 'Avengers: Infinity War',
#   'id': 299536,
#   'revenue': 2046239637,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 149},
#  {'title': 'Titanic',
#   'id': 597,
#   'revenue': 1845034188,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': None,
#   'runtime': 194},
#  {'title': 'Jurassic World',
#   'id': 135397,
#   'revenue': 1671713208,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 124},
#  {'title': 'The Lion King',
#   'id': 420818,
#   'revenue': 1656943394,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': None,
#   'runtime': 118},
#  {'title': 'The Avengers',
#   'id': 24428,
#   'revenue': 1519557910,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 143},
#  {'title': 'Furious 7',
#   'id': 168259,
#   'revenue': 1506249360,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/uv63yAGg1zETAs1XQsOQpava87l.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'runtime': 137},
#  {'title': 'Avengers: Age of Ultron',
#   'id': 99861,
#   'revenue': 1405403694,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 141},
#  {'title': 'Black Panther',
#   'id': 284054,
#   'revenue': 1346739107,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg',
#    'backdrop_path': '/1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg'},
#   'runtime': 134},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'id': 12445,
#   'revenue': 1341511219,
#   'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'},
#   'runtime': 130},
#  {'title': 'Star Wars: The Last Jedi',
#   'id': 181808,
#   'revenue': 1332539889,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 152},
#  {'title': 'Frozen II',
#   'id': 330457,
#   'revenue': 1330764959,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 104},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'id': 351286,
#   'revenue': 1303459585,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 129},
#  {'title': 'Frozen',
#   'id': 109445,
#   'revenue': 1274219009,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 102},
#  {'title': 'Beauty and the Beast',
#   'id': 321612,
#   'revenue': 1263521126,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'belongs_to_collection': None,
#   'runtime': 129},
#  {'title': 'Incredibles 2',
#   'id': 260513,
#   'revenue': 1241891456,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/l7GqbzkJwowYRIXAtUz2iCPi64a.jpg',
#    'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'},
#   'runtime': 118}]

# %%
blockbusters2
# Out:
# {'title': {'0': 'Avengers: Endgame',
#   '1': 'Avatar',
#   '2': 'Star Wars: The Force Awakens',
#   '3': 'Avengers: Infinity War',
#   '4': 'Titanic',
#   '5': 'Jurassic World',
#   '6': 'The Lion King',
#   '7': 'The Avengers',
#   '8': 'Furious 7',
#   '9': 'Avengers: Age of Ultron',
#   '10': 'Black Panther',
#   '11': 'Harry Potter and the Deathly Hallows: Part 2',
#   '12': 'Star Wars: The Last Jedi',
#   '13': 'Frozen II',
#   '14': 'Jurassic World: Fallen Kingdom',
#   '15': 'Frozen',
#   '16': 'Beauty and the Beast',
#   '17': 'Incredibles 2'},
#  'id': {'0': 299534,
#   '1': 19995,
#   '2': 140607,
#   '3': 299536,
#   '4': 597,
#   '5': 135397,
#   '6': 420818,
#   '7': 24428,
#   '8': 168259,
#   '9': 99861,
#   '10': 284054,
#   '11': 12445,
#   '12': 181808,
#   '13': 330457,
#   '14': 351286,
#   '15': 109445,
#   '16': 321612,
#   '17': 260513},
#  'revenue': {'0': 2797800564,
#   '1': 2787965087,
#   '2': 2068223624,
#   '3': 2046239637,
#   '4': 1845034188,
#   '5': 1671713208,
#   '6': 1656943394,
#   '7': 1519557910,
#   '8': 1506249360,
#   '9': 1405403694,
#   '10': 1346739107,
#   '11': 1341511219,
#   '12': 1332539889,
#   '13': 1330764959,
#   '14': 1303459585,
#   '15': 1274219009,
#   '16': 1263521126,
#   '17': 1241891456},
#  'genres': {'0': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   '1': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   '2': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   '3': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   '4': [{'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   '5': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   '6': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}],
#   '7': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   '8': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   '9': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   '10': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   '11': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   '12': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   '13': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   '14': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   '15': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'}],
#   '16': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   '17': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}]},
#  'belongs_to_collection': {'0': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   '1': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   '2': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   '3': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   '4': None,
#   '5': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   '6': None,
#   '7': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   '8': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/uv63yAGg1zETAs1XQsOQpava87l.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   '9': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   '10': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg',
#    'backdrop_path': '/1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg'},
#   '11': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'},
#   '12': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   '13': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   '14': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   '15': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   '16': None,
#   '17': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/l7GqbzkJwowYRIXAtUz2iCPi64a.jpg',
#    'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'}},
#  'runtime': {'0': 181,
#   '1': 162,
#   '2': 136,
#   '3': 149,
#   '4': 194,
#   '5': 124,
#   '6': 118,
#   '7': 143,
#   '8': 137,
#   '9': 141,
#   '10': 134,
#   '11': 130,
#   '12': 152,
#   '13': 104,
#   '14': 129,
#   '15': 102,
#   '16': 129,
#   '17': 118}}

# %%
# Convert python object blockbusters into pandas dataframes 
blockbusters_df = pd.DataFrame(blockbusters)
blockbusters_df2 = pd.DataFrame(blockbusters2)

# The loading and conversion of json objects into pandas dataframes can also done in one step instead using pd.readjson. This function is also better when converting json that's in a split format into a dataframe.
blockbusters_df3 = pd.read_json("blockbusters3.json", orient="split")

# %%
blockbusters_df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
blockbusters_df2
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
blockbusters_df3
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
# The data in the blockbusters_df dataframe is nested. Normalise the data. The data in the blockbusters_df2 and blockbusters_df3 dataframes are also nested but cannot be normalised using pd.json_normalize as these dataframes were imported from json files in column and split formats. 

# Normalise belongs_to_collection column
collection_norm_df = pd.json_normalize(data = blockbusters, sep= "_")

# Normalise genres column
genre_norm_df = pd.json_normalize(data = blockbusters, record_path="genres", meta=["id"], record_prefix="genre_")

# Append normalised genre column to dataframe with normalised collection column
blockbusters_norm_df = collection_norm_df.drop(columns="genres").merge(genre_norm_df, how = "inner", on="id")
blockbusters_norm_df
# Out:
#                                            title      id     revenue  runtime  \
# 0                              Avengers: Endgame  299534  2797800564      181
# 1                              Avengers: Endgame  299534  2797800564      181
# 2                              Avengers: Endgame  299534  2797800564      181
# 3                                         Avatar   19995  2787965087      162
# 4                                         Avatar   19995  2787965087      162
# 5                                         Avatar   19995  2787965087      162
# 6                                         Avatar   19995  2787965087      162
# 7                   Star Wars: The Force Awakens  140607  2068223624      136
# 8                   Star Wars: The Force Awakens  140607  2068223624      136
# 9                   Star Wars: The Force Awakens  140607  2068223624      136
# 10                  Star Wars: The Force Awakens  140607  2068223624      136
# 11                        Avengers: Infinity War  299536  2046239637      149
# 12                        Avengers: Infinity War  299536  2046239637      149
# 13                        Avengers: Infinity War  299536  2046239637      149
# 14                                       Titanic     597  1845034188      194
# 15                                       Titanic     597  1845034188      194
# 16                                       Titanic     597  1845034188      194
# 17                                Jurassic World  135397  1671713208      124
# 18                                Jurassic World  135397  1671713208      124
# 19                                Jurassic World  135397  1671713208      124
# 20                                Jurassic World  135397  1671713208      124
# 21                                 The Lion King  420818  1656943394      118
# 22                                 The Lion King  420818  1656943394      118
# 23                                  The Avengers   24428  1519557910      143
# 24                                  The Avengers   24428  1519557910      143
# 25                                  The Avengers   24428  1519557910      143
# 26                                     Furious 7  168259  1506249360      137
# 27                                     Furious 7  168259  1506249360      137
# 28                       Avengers: Age of Ultron   99861  1405403694      141
# 29                       Avengers: Age of Ultron   99861  1405403694      141
# 30                       Avengers: Age of Ultron   99861  1405403694      141
# 31                                 Black Panther  284054  1346739107      134
# 32                                 Black Panther  284054  1346739107      134
# 33                                 Black Panther  284054  1346739107      134
# 34                                 Black Panther  284054  1346739107      134
# 35  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219      130
# 36  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219      130
# 37                      Star Wars: The Last Jedi  181808  1332539889      152
# 38                      Star Wars: The Last Jedi  181808  1332539889      152
# 39                      Star Wars: The Last Jedi  181808  1332539889      152
# 40                      Star Wars: The Last Jedi  181808  1332539889      152
# 41                                     Frozen II  330457  1330764959      104
# 42                                     Frozen II  330457  1330764959      104
# 43                                     Frozen II  330457  1330764959      104
# 44                Jurassic World: Fallen Kingdom  351286  1303459585      129
# 45                Jurassic World: Fallen Kingdom  351286  1303459585      129
# 46                Jurassic World: Fallen Kingdom  351286  1303459585      129
# 47                                        Frozen  109445  1274219009      102
# 48                                        Frozen  109445  1274219009      102
# 49                                        Frozen  109445  1274219009      102
# 50                          Beauty and the Beast  321612  1263521126      129
# 51                          Beauty and the Beast  321612  1263521126      129
# 52                          Beauty and the Beast  321612  1263521126      129
# 53                                 Incredibles 2  260513  1241891456      118
# 54                                 Incredibles 2  260513  1241891456      118
# 55                                 Incredibles 2  260513  1241891456      118
# 56                                 Incredibles 2  260513  1241891456      118
#
#     belongs_to_collection_id           belongs_to_collection_name  \
# 0                    86311.0              The Avengers Collection
# 1                    86311.0              The Avengers Collection
# 2                    86311.0              The Avengers Collection
# 3                    87096.0                    Avatar Collection
# 4                    87096.0                    Avatar Collection
# 5                    87096.0                    Avatar Collection
# 6                    87096.0                    Avatar Collection
# 7                       10.0                 Star Wars Collection
# 8                       10.0                 Star Wars Collection
# 9                       10.0                 Star Wars Collection
# 10                      10.0                 Star Wars Collection
# 11                   86311.0              The Avengers Collection
# 12                   86311.0              The Avengers Collection
# 13                   86311.0              The Avengers Collection
# 14                       NaN                                  NaN
# 15                       NaN                                  NaN
# 16                       NaN                                  NaN
# 17                     328.0             Jurassic Park Collection
# 18                     328.0             Jurassic Park Collection
# 19                     328.0             Jurassic Park Collection
# 20                     328.0             Jurassic Park Collection
# 21                       NaN                                  NaN
# 22                       NaN                                  NaN
# 23                   86311.0              The Avengers Collection
# 24                   86311.0              The Avengers Collection
# 25                   86311.0              The Avengers Collection
# 26                    9485.0  The Fast and the Furious Collection
# 27                    9485.0  The Fast and the Furious Collection
# 28                   86311.0              The Avengers Collection
# 29                   86311.0              The Avengers Collection
# 30                   86311.0              The Avengers Collection
# 31                  529892.0             Black Panther Collection
# 32                  529892.0             Black Panther Collection
# 33                  529892.0             Black Panther Collection
# 34                  529892.0             Black Panther Collection
# 35                    1241.0              Harry Potter Collection
# 36                    1241.0              Harry Potter Collection
# 37                      10.0                 Star Wars Collection
# 38                      10.0                 Star Wars Collection
# 39                      10.0                 Star Wars Collection
# 40                      10.0                 Star Wars Collection
# 41                  386382.0                    Frozen Collection
# 42                  386382.0                    Frozen Collection
# 43                  386382.0                    Frozen Collection
# 44                     328.0             Jurassic Park Collection
# 45                     328.0             Jurassic Park Collection
# 46                     328.0             Jurassic Park Collection
# 47                  386382.0                    Frozen Collection
# 48                  386382.0                    Frozen Collection
# 49                  386382.0                    Frozen Collection
# 50                       NaN                                  NaN
# 51                       NaN                                  NaN
# 52                       NaN                                  NaN
# 53                  468222.0           The Incredibles Collection
# 54                  468222.0           The Incredibles Collection
# 55                  468222.0           The Incredibles Collection
# 56                  468222.0           The Incredibles Collection
#
#    belongs_to_collection_poster_path belongs_to_collection_backdrop_path  \
# 0   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 1   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 2   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 3   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 4   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 5   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 6   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 7   /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 8   /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 9   /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 10  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 11  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 12  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 13  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 14                               NaN                                 NaN
# 15                               NaN                                 NaN
# 16                               NaN                                 NaN
# 17  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 18  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 19  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 20  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 21                               NaN                                 NaN
# 22                               NaN                                 NaN
# 23  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 24  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 25  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 26  /uv63yAGg1zETAs1XQsOQpava87l.jpg    /z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg
# 27  /uv63yAGg1zETAs1XQsOQpava87l.jpg    /z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg
# 28  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 29  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 30  /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 31  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 32  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 33  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 34  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 35  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg
# 36  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg
# 37  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 38  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 39  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 40  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 41  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 42  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 43  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 44  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 45  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 46  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 47  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 48  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 49  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 50                               NaN                                 NaN
# 51                               NaN                                 NaN
# 52                               NaN                                 NaN
# 53  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
# 54  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
# 55  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
# 56  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
#
#     belongs_to_collection  genre_id       genre_name
# 0                     NaN        12        Adventure
# 1                     NaN       878  Science Fiction
# 2                     NaN        28           Action
# 3                     NaN        28           Action
# 4                     NaN        12        Adventure
# 5                     NaN        14          Fantasy
# 6                     NaN       878  Science Fiction
# 7                     NaN        28           Action
# 8                     NaN        12        Adventure
# 9                     NaN       878  Science Fiction
# 10                    NaN        14          Fantasy
# 11                    NaN        12        Adventure
# 12                    NaN        28           Action
# 13                    NaN       878  Science Fiction
# 14                    NaN        18            Drama
# 15                    NaN     10749          Romance
# 16                    NaN        53         Thriller
# 17                    NaN        28           Action
# 18                    NaN        12        Adventure
# 19                    NaN       878  Science Fiction
# 20                    NaN        53         Thriller
# 21                    NaN        12        Adventure
# 22                    NaN     10751           Family
# 23                    NaN       878  Science Fiction
# 24                    NaN        28           Action
# 25                    NaN        12        Adventure
# 26                    NaN        28           Action
# 27                    NaN        53         Thriller
# 28                    NaN        28           Action
# 29                    NaN        12        Adventure
# 30                    NaN       878  Science Fiction
# 31                    NaN        28           Action
# 32                    NaN        12        Adventure
# 33                    NaN        14          Fantasy
# 34                    NaN       878  Science Fiction
# 35                    NaN        14          Fantasy
# 36                    NaN        12        Adventure
# 37                    NaN        14          Fantasy
# 38                    NaN        12        Adventure
# 39                    NaN       878  Science Fiction
# 40                    NaN        28           Action
# 41                    NaN        16        Animation
# 42                    NaN     10751           Family
# 43                    NaN        12        Adventure
# 44                    NaN        28           Action
# 45                    NaN        12        Adventure
# 46                    NaN       878  Science Fiction
# 47                    NaN        16        Animation
# 48                    NaN        12        Adventure
# 49                    NaN     10751           Family
# 50                    NaN     10751           Family
# 51                    NaN        14          Fantasy
# 52                    NaN     10749          Romance
# 53                    NaN        28           Action
# 54                    NaN        12        Adventure
# 55                    NaN        16        Animation
# 56                    NaN     10751           Family

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %% [markdown]
# __API-Request__: Load all available information for the movie with __movie id = 140607__ using the TMDB database API and save as a Pandas DataFrame.

# %%
# Generate the URL for an API request for the movie with id = 140607 from the TMDB database
movie_id = "140607"
api_key = "96944f8e497f77db9d20db6e35c77804"
url = "https://api.themoviedb.org/3/movie/" + movie_id + "?api_key=" + api_key + "&language=en-US"
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=96944f8e497f77db9d20db6e35c77804&language=en-US'

# %%
# Request the movie information
request = requests.get(url)
request
# Out:
# <Response [200]>

# %%
# Return the request information as a json object
request_json = request.json()
request_json
# Out:
# {'adult': False,
#  'backdrop_path': '/8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/gq5Wi7i4SF3lo4HHkJasDV95xI9.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  'budget': 245000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#  'id': 140607,
#  'imdb_id': 'tt2488496',
#  'original_language': 'en',
#  'original_title': 'Star Wars: The Force Awakens',
#  'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#  'popularity': 66.464,
#  'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#  'production_companies': [{'id': 1,
#    'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png',
#    'name': 'Lucasfilm Ltd.',
#    'origin_country': 'US'},
#   {'id': 11461,
#    'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#    'name': 'Bad Robot',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2015-12-15',
#  'revenue': 2068223624,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Every generation has a story.',
#  'title': 'Star Wars: The Force Awakens',
#  'video': False,
#  'vote_average': 7.31,
#  'vote_count': 17472}

# %%
# Convert the json object into a pandas dataframe
starwars_df = pd.Series(request_json).to_frame().transpose()
starwars_df
# Out:
#    adult                     backdrop_path  \
# 0  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  ... release_date  \
# 0                en  Star Wars: The Force Awakens  ...   2015-12-15
#
#       revenue runtime                                   spoken_languages  \
# 0  2068223624     136  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#      status                        tagline                         title  \
# 0  Released  Every generation has a story.  Star Wars: The Force Awakens
#
#    video vote_average vote_count
# 0  False         7.31      17472
#
# [1 rows x 25 columns]

# %%
# Normalise data
# Normalise columns separately
belongs_to_collection_norm = pd.json_normalize(request_json).drop(columns="genres")
genres_norm = pd.json_normalize(request_json,record_path="genres",meta=["title"],record_prefix="genre_")
production_companies_norm = pd.json_normalize(request_json,record_path="production_companies",meta="title",record_prefix="production_company_")
production_countries_norm = pd.json_normalize(request_json,record_path="production_countries",meta="title",record_prefix="production_country_")
spoken_languages_norm = pd.json_normalize(request_json,record_path="spoken_languages",meta="title",record_prefix="spoken_language_")

# Combine normalised data using partial and reduce functions. Partial freezes a portion of a function's arguments and keywords, while reduce allows appliation of an iterable list of objects to the partial object.
dfs = [belongs_to_collection_norm, genres_norm, production_companies_norm, production_countries_norm, spoken_languages_norm]
merge = partial(pd.merge, on="title")
starwars_df_norm = reduce(merge,dfs)
starwars_df_norm
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 1  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 3  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 4  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 5  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 6  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
# 7  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg  245000000
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 1  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 4  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 5  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 6  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 7  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
# 1                en  Star Wars: The Force Awakens
# 2                en  Star Wars: The Force Awakens
# 3                en  Star Wars: The Force Awakens
# 4                en  Star Wars: The Force Awakens
# 5                en  Star Wars: The Force Awakens
# 6                en  Star Wars: The Force Awakens
# 7                en  Star Wars: The Force Awakens
#
#                                             overview  popularity  ...  \
# 0  Thirty years after defeating the Galactic Empi...      66.464  ...
# 1  Thirty years after defeating the Galactic Empi...      66.464  ...
# 2  Thirty years after defeating the Galactic Empi...      66.464  ...
# 3  Thirty years after defeating the Galactic Empi...      66.464  ...
# 4  Thirty years after defeating the Galactic Empi...      66.464  ...
# 5  Thirty years after defeating the Galactic Empi...      66.464  ...
# 6  Thirty years after defeating the Galactic Empi...      66.464  ...
# 7  Thirty years after defeating the Galactic Empi...      66.464  ...
#
#         genre_name production_company_id      production_company_logo_path  \
# 0        Adventure                     1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 1        Adventure                 11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
# 2           Action                     1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 3           Action                 11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
# 4  Science Fiction                     1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 5  Science Fiction                 11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
# 6          Fantasy                     1  /o86DbpburjxrqAzEDhXZcyE8pDb.png
# 7          Fantasy                 11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png
#
#   production_company_name  production_company_origin_country  \
# 0          Lucasfilm Ltd.                                 US
# 1               Bad Robot                                 US
# 2          Lucasfilm Ltd.                                 US
# 3               Bad Robot                                 US
# 4          Lucasfilm Ltd.                                 US
# 5               Bad Robot                                 US
# 6          Lucasfilm Ltd.                                 US
# 7               Bad Robot                                 US
#
#    production_country_iso_3166_1   production_country_name  \
# 0                             US  United States of America
# 1                             US  United States of America
# 2                             US  United States of America
# 3                             US  United States of America
# 4                             US  United States of America
# 5                             US  United States of America
# 6                             US  United States of America
# 7                             US  United States of America
#
#   spoken_language_english_name spoken_language_iso_639_1 spoken_language_name
# 0                      English                        en              English
# 1                      English                        en              English
# 2                      English                        en              English
# 3                      English                        en              English
# 4                      English                        en              English
# 5                      English                        en              English
# 6                      English                        en              English
# 7                      English                        en              English
#
# [8 rows x 38 columns]

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %% [markdown]
# 5. __API-Request__ (discover module): Load all movies with __release date between 2020-01-01 and 2020-02-29__ into a Pandas DataFrame. <br>
# See https://www.themoviedb.org/documentation/api/discover and https://developers.themoviedb.org/3/discover/movie-discover for more information.

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %% [markdown]
# 6. __API-Request__ (movie module): Load all available information for the movies with movie id = [__299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513__] into a Pandas DataFrame and __save the dataset in a local json file__.

# %% [markdown]
# # +++++++++ See some Hints below +++++++++++++

# %% [markdown]
# # ++++++++++++++ Hints +++++++++++++++++++++

# %% [markdown]
# __Hints for 1.__ <br>
# To load json files you can use

# %%
with open("filename.json") as f:
    data = json.load(f)

# %% [markdown]
# and

# %%
pd.DataFrame(data), pd.read_json(filename.json), pd.json_normalize(data)

# %% [markdown]
# the json files have the following orientation (important when using pd.read_json()):
# - blockbusters.json -> record
# - blockbusters2.json -> column
# - blockbusters3.json -> split

# %% [markdown]
# __Hints for 4., 5., 6.__<br>
# Make API GET-requests with the library requests (import requests):

# %%
data = requests.get(url).json()

# %% [markdown]
# __Hints for 4. and 6.,__ <br> url structure for movie module:

# %% [markdown]
# "https://api.themoviedb.org/3/movie/insert_movie_id?api_key=insert_api_key" (replace "insert_movie_id" with movie id and "insert_api_key" with your personal api-key)

# %% [markdown]
# __Hints for 5.__<br>
# url structure for discover module:

# %% [markdown]
# "https://api.themoviedb.org/3/discover/movie?api_key=insert_api_key&query1&query2..." (replace "insert_api_key" with your personal api-key and add appropriate queries)
